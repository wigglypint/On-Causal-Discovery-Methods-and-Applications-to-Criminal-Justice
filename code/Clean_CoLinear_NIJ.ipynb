# %%
from pathlib import Path
import pandas as pd
import numpy as np

#set project root as .../recidivism-causal
project_root = Path("/dcs/23/u2200504/thesis/recidivism-causal").resolve()

#set nij root
nij_root = project_root / "data" / "processed"
#test it works
nij_root

#path to dataset
csv_path = nij_root/"NIJ_clean.csv"

#load into df and sanity check form
df = pd.read_csv(csv_path)
df.head(), df.shape

#deal with perfectly deterministic columns by only keeping one representative, good hygeine
cols_to_drop= [
    "Gender_M",
    "Gang_Affiliated_Missing", #encoded via gender_F
    "DrugTests_Cocaine_Positive_Missing", #handle drug test missingness, since one determines the value of all others, we keep THC and drop the rest
    "DrugTests_Meth_Positive_Missing",
    "DrugTests_Other_Positive_Missing",
    #race, only black or white so just keep one
    "Race_WHITE",
    #just drop as unnecessary
    "ID",
    "Training_Sample"
]
df_clean = df.drop(columns=cols_to_drop, errors="ignore")

df_clean.to_csv("NIJ_compact.csv", index=False)
